# %%
import pandas as pd
#loading the accedents dataset to dataframe
# Defining the columns to read
usecols = ["TypeAcid"]

# Read data with subset of columns

ac_data = pd.read_csv("datav3.csv")
ac_data.head()
# Out:
#    case                       TypeAcid  TotalDrivers  DeadPeople  \
# 0     1           Collision with a car             4         2.0
# 1     2                      Overturns             1         1.0
# 2     3            Pedestrian run over             2         1.0
# 3     4  Collision with a fixed object             2         0.0
# 4     5  Collision with a fixed object             1         1.0
#
#    Total_injuries  Unharmed TypePlace   WeekDay Month  HourNear  ... Severity  \
# 0               2         0     Paved    Friday     1   5:00 AM  ...      Yes
# 1               0         0     Paved    Friday     1   5:00 PM  ...      Yes
# 2               0         1     Paved    Friday     1  12:00 PM  ...      Yes
# 3               2         0     Paved    Friday     1  12:00 PM  ...      Yes
# 4               0         0     Paved  Saturday     1   7:30 PM  ...      Yes
#
#    DayOfYear  DayShift  Holidays  AccidentCause AccidentClassification  \
# ...

# %%
ac_data.shape
# Out:
# (2058, 25)

# %%
#Information about the dataset
ac_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2058 entries, 0 to 2057
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case                    2058 non-null   int64
#  1   TypeAcid                2058 non-null   object
#  2   TotalDrivers            2058 non-null   int64
#  3   DeadPeople              2057 non-null   float64
#  4   Total_injuries          2058 non-null   int64
#  5   Unharmed                2058 non-null   int64
#  6   TypePlace               2058 non-null   object
#  7   WeekDay                 2058 non-null   object
#  8   Month                   2057 non-null   object
#  9   HourNear                2058 non-null   object
#  10  Motorcycle              2058 non-null   object
#  11  HeavyVehicle            2057 non-null   float64
#  12  LightVehicle            2057 non-null   float64
#  13  Vehicle                 2057 non-null   float64
# ...

# %%
#Plotting the data distribution
import matplotlib.pyplot as plt
ac_data.hist(bins = 50,figsize = (15,15))
plt.show()

# %%
# Data Preprocessing & EDA
# Here, we clean the data by applying data preprocesssing techniques and transform the data to use it in the models.


ac_data.describe()
# Out:
#               case  TotalDrivers   DeadPeople  Total_injuries     Unharmed  \
# count  2058.000000   2058.000000  2057.000000     2058.000000  2058.000000
# mean   1038.707483      2.629252     0.549344        1.550534     0.568027
# std     601.683145      2.050898     0.876976        1.721387     0.781711
# min       1.000000      0.000000     0.000000        0.000000     0.000000
# 25%     515.250000      2.000000     0.000000        1.000000     0.000000
# 50%    1044.500000      2.000000     0.000000        1.000000     0.000000
# 75%    1561.750000      3.000000     1.000000        2.000000     1.000000
# max    2072.000000     49.000000    21.000000       28.000000     7.000000
#
#        HeavyVehicle  LightVehicle      Vehicle    DayOfYear          Year  \
# count   2057.000000   2057.000000  2057.000000  2058.000000   2058.000000
# mean       0.530384      0.928051     1.465241    15.848397   2030.568513
# ...

# %%
# The Latitude/Longitude
# column doesnt have any significance to the machine learning model training. So dropping the 'Latitude/Longitude
#' column from the dataset.


#Dropping the Domain column
data = ac_data.drop(['Latitude/Longitude'], axis = 1).copy()
data.head()
# Out:
#    case                       TypeAcid  TotalDrivers  DeadPeople  \
# 0     1           Collision with a car             4         2.0
# 1     2                      Overturns             1         1.0
# 2     3            Pedestrian run over             2         1.0
# 3     4  Collision with a fixed object             2         0.0
# 4     5  Collision with a fixed object             1         1.0
#
#    Total_injuries  Unharmed TypePlace   WeekDay Month  HourNear  ... RoadType  \
# 0               2         0     Paved    Friday     1   5:00 AM  ...    Paved
# 1               0         0     Paved    Friday     1   5:00 PM  ...    Paved
# 2               0         1     Paved    Friday     1  12:00 PM  ...    Paved
# 3               2         0     Paved    Friday     1  12:00 PM  ...    Paved
# 4               0         0     Paved  Saturday     1   7:30 PM  ...    Paved
#
#    Severity  DayOfYear  DayShift Holidays  AccidentCause  \
# ...

# %%
#checking the data for null or missing values
data.isnull().sum()
